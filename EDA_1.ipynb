# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel("Flight_Fare.xlsx")

# %%
df
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 0           IndiGo      24/03/2019  Banglore   New Delhi
# 1        Air India       1/05/2019   Kolkata    Banglore
# 2      Jet Airways       9/06/2019     Delhi      Cochin
# 3           IndiGo      12/05/2019   Kolkata    Banglore
# 4           IndiGo      01/03/2019  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10678     Air Asia       9/04/2019   Kolkata    Banglore
# 10679    Air India      27/04/2019   Kolkata    Banglore
# 10680  Jet Airways      27/04/2019  Banglore       Delhi
# 10681      Vistara      01/03/2019  Banglore   New Delhi
# 10682    Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0                  BLR → DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# 1      CCU → IXR → BBI → BLR    05:50         13:15   7h 25m     2 stops
# ...

# %%
#Changing Duration into minutes

# %%
for i in range(0,6475):
    temp=df['Duration'][i]
    hours = int(temp.split('h')[0].strip())
    mins = 0
    if i != 6474:
        if temp.split('h')[1]!='':
            mins = int(temp.split('h')[1].strip('m').strip())
        print(hours,mins)
        df['Duration'][i] = hours*60 + mins
# Out:
# 2 50
# 7 25
# 19 0
# 5 25
# 4 45
# 2 25
# 15 30
# 21 5
# 25 30
# 7 50
# 13 15
# 2 35
# 2 15
# 12 10
# 2 35
# 26 35
# 4 30
# 22 35
# 23 0
# 20 35
# 5 10
# 15 20
# 2 50
# 2 55
# 13 20
# 15 10
# 5 45
# 5 55
# 2 50
# 2 15
# 2 15
# 13 25
# 2 50
# 22 0
# 5 30
# 10 25
# 5 15
# 2 30
# 6 15
# 11 55
# 11 5
# 8 30
# 22 5
# 2 45
# 12 0
# 2 50
# 2 50
# 2 15
# 16 5
# 19 55
# 3 15
# 25 20
# 2 50
# 3 0
# 2 50
# 16 15
# 15 5
# 2 15
# 6 30
# 25 5
# 12 25
# 27 20
# 10 15
# 10 30
# 2 15
# 10 25
# 2 50
# 1 30
# 13 20
# 2 15
# 1 25
# 26 30
# 7 20
# 13 30
# 5 0
# 2 45
# 2 50
# 1 30
# 19 5
# 2 15
# 14 50
# 2 40
# 22 10
# 9 35
# 10 0
# 21 20
# 5 25
# 18 45
# 12 20
# 18 0
# 9 15
# 11 5
# 17 30
# 13 20
# 2 35
# 2 25
# 2 40
# 3 0
# 1 25
# 16 35
# 12 20
# 12 15
# 7 30
# 24 0
# 2 45
# 8 55
# 7 10
# 14 30
# 30 20
# 19 55
# 15 0
# 2 55
# 12 45
# 10 10
# 5 55
# 15 25
# 16 5
# 10 10
# 2 40
# 11 55
# 2 40
# 1 25
# 14 5
# 20 15
# 2 25
# 23 10
# 18 10
# 16 0
# 2 50
# 2 20
# 8 0
# 16 55
# 3 10
# 2 45
# 14 0
# 23 50
# ...

# %%
for i in range(6475,len(df)):
    temp=df['Duration'][i]
    hours = int(temp.split('h')[0].strip())
    mins = 0
    if i != 6474:
        if temp.split('h')[1]!='':
            mins = int(temp.split('h')[1].strip('m').strip())
        print(hours,mins)
        df['Duration'][i] = hours*60 + mins
# Out:
# 2 50
# 38 35
# 5 30
# 26 30
# 2 55
# 1 30
# 4 25
# 1 25
# 1 25
# 4 0
# 2 55
# 5 5
# 2 40
# 8 25
# 2 50
# 13 0
# 9 30
# 20 25
# 2 40
# 30 0
# 14 50
# 2 40
# 2 50
# 2 35
# 24 0
# 13 20
# 9 35
# 1 25
# 9 45
# 16 45
# 2 45
# 11 0
# 8 15
# 2 20
# 4 25
# 24 35
# 3 0
# 21 40
# 1 35
# 2 40
# 16 15
# 12 55
# 2 40
# 11 45
# 2 20
# 2 45
# 2 50
# 3 15
# 3 15
# 2 45
# 17 5
# 2 40
# 3 15
# 2 50
# 11 55
# 14 10
# 2 35
# 23 35
# 11 45
# 2 55
# 1 30
# 7 5
# 2 20
# 14 0
# 1 25
# 10 40
# 9 30
# 25 45
# 12 0
# 2 50
# 2 50
# 21 20
# 13 20
# 6 35
# 3 15
# 1 30
# 5 35
# 8 0
# 2 45
# 2 55
# 9 50
# 5 45
# 25 45
# 2 50
# 22 25
# 11 55
# 7 30
# 3 5
# 2 35
# 7 30
# 7 30
# 14 5
# 14 45
# 22 15
# 6 15
# 6 30
# 2 55
# 2 30
# 1 15
# 4 5
# 8 25
# 14 50
# 17 35
# 3 0
# 2 50
# 18 45
# 2 35
# 1 25
# 27 10
# 2 35
# 5 45
# 6 25
# 9 30
# 8 50
# 5 55
# 5 5
# 6 35
# 2 35
# 2 55
# 2 50
# 11 15
# 7 55
# 9 0
# 23 20
# 13 55
# 10 25
# 6 35
# 7 20
# 10 25
# 12 25
# 14 20
# 12 5
# 3 0
# 3 0
# 17 25
# 27 10
# 8 55
# 15 0
# 2 45
# ...

# %%
df.loc[6474,'Duration']=5

# %%
df
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 0           IndiGo      24/03/2019  Banglore   New Delhi
# 1        Air India       1/05/2019   Kolkata    Banglore
# 2      Jet Airways       9/06/2019     Delhi      Cochin
# 3           IndiGo      12/05/2019   Kolkata    Banglore
# 4           IndiGo      01/03/2019  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10678     Air Asia       9/04/2019   Kolkata    Banglore
# 10679    Air India      27/04/2019   Kolkata    Banglore
# 10680  Jet Airways      27/04/2019  Banglore       Delhi
# 10681      Vistara      01/03/2019  Banglore   New Delhi
# 10682    Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0                  BLR → DEL    22:20  01:10 22 Mar      170    non-stop
# 1      CCU → IXR → BBI → BLR    05:50         13:15      445     2 stops
# ...

# %%
df['Duration'] = pd.to_numeric(df['Duration'])

# %%
df['Duration']
# Out:
# 0         170
# 1         445
# 2        1140
# 3         325
# 4         285
#          ...
# 10678     150
# 10679     155
# 10680     180
# 10681     160
# 10682     500
# Name: Duration, Length: 10683, dtype: int64

# %%
#ploting boxplot to find outliers and analyze duration
df.boxplot(column=['Duration'])
# Out:
# <AxesSubplot:>

# %%
durations = df['Duration']

# %%
durations.sort_values(ascending=True)
# Out:
# 6474        5
# 4806       75
# 1416       75
# 2083       75
# 3986       75
#          ...
# 7906     2480
# 5953     2525
# 8409     2565
# 1067     2820
# 10456    2860
# Name: Duration, Length: 10683, dtype: int64

# %%
df[df['Duration']==min(df['Duration'])]
# Out:
#         Airline Date_of_Journey  Source Destination                  Route  \
# 6474  Air India       6/03/2019  Mumbai   Hyderabad  BOM → GOI → PNQ → HYD
#
#      Dep_Time Arrival_Time  Duration Total_Stops Additional_Info  Price
# 6474    16:50        16:55         5     2 stops         No info  17327

# %% [markdown]
# #### Mumbai to Goa flight generally takes 70 minutes non stop
# #### Goa to Pune generally takes 60 minutes non stop
# #### Pune to Hyderabad generally takes 70 minutes non stop
# #### consequently it should take around 200 minutes to reach from mumbai to Hyderabad

# %%
df['Duration'][6474]=200
df['Duration'] = df['Duration'].replace(5,200)
# Out:
# C:\Users\user\AppData\Local\Temp/ipykernel_24704/75259765.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Duration'][6474]=200

# %%
df[df['Duration']==max(df['Duration'])]
# Out:
#            Airline Date_of_Journey Source Destination                  Route  \
# 10456  Jet Airways       6/03/2019  Delhi      Cochin  DEL → AMD → BOM → COK
#
#       Dep_Time  Arrival_Time  Duration Total_Stops Additional_Info  Price
# 10456    19:10  18:50 08 Mar      2860     2 stops         No info  20694

# %%
df['Total_Stops'].unique()
# Out:
# array(['non-stop', '2 stops', '1 stop', '3 stops', nan, '4 stops'],
#       dtype=object)

# %%
#since it is hard to analyze duration when we consider it altogether
#Therfore we will increase its granularity by considering column Total stops because this is directly propotional to duration

# %%
df[df['Total_Stops']=='non-stop'].boxplot(column='Duration')
# Out:
# <AxesSubplot:>

# %%
df[df['Total_Stops']=='1 stop'].boxplot(column='Duration')
# Out:
# <AxesSubplot:>

# %%
df[df['Total_Stops']=='2 stops'].boxplot(column='Duration')
# Out:
# <AxesSubplot:>

# %%
df[df['Total_Stops']=='3 stops'].boxplot(column='Duration')
# Out:
# <AxesSubplot:>

# %%
#Now we will find the total flights arrived to given cities

# %%
for i in df['Destination'].unique():
    print(i,df[df['Destination']==i]['Destination'].count())
# Out:
# New Delhi 932
# Banglore 2871
# Cochin 4537
# Kolkata 381
# Delhi 1265
# Hyderabad 697

# %% [markdown]
# ##### Maximum flights (4537)  arrives at cochin

# %%
for i in df['Source'].unique():
    print(i,df[df['Source']==i]['Source'].count())
# Out:
# Banglore 2197
# Kolkata 2871
# Delhi 4537
# Chennai 381
# Mumbai 697

# %% [markdown]
# ##### Maximum flights (4537) departs from Delhi

# %% [markdown]
# ###### It means that from thses cities one can find tickets with minimal cost with high availability
# ~According to data on websites

# %%
#saving the  new version where we have applied changes
df.to_csv('flight_fare1.csv')

# %%
import pandas as pd

# %%
df = pd.read_csv('flight_fare1.csv')

# %%
df
# Out:
#        Unnamed: 0      Airline Date_of_Journey    Source Destination  \
# 0               0       IndiGo      24/03/2019  Banglore   New Delhi
# 1               1    Air India       1/05/2019   Kolkata    Banglore
# 2               2  Jet Airways       9/06/2019     Delhi      Cochin
# 3               3       IndiGo      12/05/2019   Kolkata    Banglore
# 4               4       IndiGo      01/03/2019  Banglore   New Delhi
# ...           ...          ...             ...       ...         ...
# 10678       10678     Air Asia       9/04/2019   Kolkata    Banglore
# 10679       10679    Air India      27/04/2019   Kolkata    Banglore
# 10680       10680  Jet Airways      27/04/2019  Banglore       Delhi
# 10681       10681      Vistara      01/03/2019  Banglore   New Delhi
# 10682       10682    Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time  Arrival_Time  Duration Total_Stops  \
# ...

# %%
df['Total_Stops'].unique()
# Out:
# array(['non-stop', '2 stops', '1 stop', '3 stops', nan, '4 stops'],
#       dtype=object)

# %% [markdown]
# ### I could have used a direct method
#
# df['Total_Stops'] = df['Total_Stops].replace(['non-stop', '2 stops', '1 stop', '3 stops', '4 stops'],[0,2,1,3,4])

# %%
#Changing datatype of total stops 
#total stops is of object type we will convert it to int type for example '1 stop' ~~> 1

# %%
for i in range(len(df)):
    if df['Total_Stops'][i]=='non-stop':
        df.loc[i,'Total_Stops']=0
    if df['Total_Stops'][i]=='1 stop':
        df.loc[i,'Total_Stops']=1
    if df['Total_Stops'][i]=='2 stops':
        df.loc[i,'Total_Stops']=2
    if df['Total_Stops'][i]=='3 stops':
        df.loc[i,'Total_Stops']=3
    if df['Total_Stops'][i]=='4 stops':
        df.loc[i,'Total_Stops']=4

# %%
df['Total_Stops'][3]
# Out:
# 1

# %%
print(len(df))
# Out:
# 10683

# %%
df
# Out:
#        Unnamed: 0      Airline Date_of_Journey    Source Destination  \
# 0               0       IndiGo      24/03/2019  Banglore   New Delhi
# 1               1    Air India       1/05/2019   Kolkata    Banglore
# 2               2  Jet Airways       9/06/2019     Delhi      Cochin
# 3               3       IndiGo      12/05/2019   Kolkata    Banglore
# 4               4       IndiGo      01/03/2019  Banglore   New Delhi
# ...           ...          ...             ...       ...         ...
# 10678       10678     Air Asia       9/04/2019   Kolkata    Banglore
# 10679       10679    Air India      27/04/2019   Kolkata    Banglore
# 10680       10680  Jet Airways      27/04/2019  Banglore       Delhi
# 10681       10681      Vistara      01/03/2019  Banglore   New Delhi
# 10682       10682    Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time  Arrival_Time  Duration Total_Stops  \
# ...

# %%
df['Total_Stops'].unique()
# Out:
# array([0, 2, 1, 3, nan, 4], dtype=object)

# %%
#finding NULL values

# %%
df[df['Total_Stops'].isna()]
# Out:
#       Unnamed: 0    Airline Date_of_Journey Source Destination Route Dep_Time  \
# 9039        9039  Air India       6/05/2019  Delhi      Cochin   NaN    09:45
#
#       Arrival_Time  Duration Total_Stops Additional_Info  Price
# 9039  09:25 07 May      1420         NaN         No info   7480

# %% [markdown]
# ### according to data on websites the route of this kind flight takes place like this Delhi->Bangaluru->Cochin

# %% [markdown]
# #### therefore Total_stops = 1
# #### Route = DEL->BAL->COK

# %%
#substituting null values 
df.loc[9039,'Total_Stops']= 1
df.loc[9039,'Route']= 'DEL->BAL->COK'

# %%
df.iloc[9039]
# Out:
# Unnamed: 0                  9039
# Airline                Air India
# Date_of_Journey        6/05/2019
# Source                     Delhi
# Destination               Cochin
# Route              DEL->BAL->COK
# Dep_Time                   09:45
# Arrival_Time        09:25 07 May
# Duration                    1420
# Total_Stops                    1
# Additional_Info          No info
# Price                       7480
# Name: 9039, dtype: object

# %%
df.isna().sum()
#Now we dont have any null values
# Out:
# Unnamed: 0         0
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Route              0
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        0
# Additional_Info    0
# Price              0
# dtype: int64

# %%
df.boxplot(column=['Price'])
# Out:
# <AxesSubplot:>

# %%
df[df['Total_Stops']==0].boxplot(column=['Price'])
# Out:
# <AxesSubplot:>

# %%
min(df[df['Total_Stops']==0]['Price'])
# Out:
# 1759

# %%
max(df[df['Total_Stops']==0]['Price'])
# Out:
# 31945

# %%
df[df['Price']==31945]
# Out:
#        Unnamed: 0    Airline Date_of_Journey   Source Destination      Route  \
# 10052       10052  Air India      24/03/2019  Kolkata    Banglore  CCU → BLR
#
#       Dep_Time Arrival_Time  Duration Total_Stops Additional_Info  Price
# 10052    20:45        23:20       155           0         No info  31945

# %%
df[df['Total_Stops']==1].boxplot(column=['Price'])
# Out:
# <AxesSubplot:>

# %%
df[df['Price']==31945]
# Out:
#        Unnamed: 0    Airline Date_of_Journey   Source Destination      Route  \
# 10052       10052  Air India      24/03/2019  Kolkata    Banglore  CCU → BLR
#
#       Dep_Time Arrival_Time  Duration Total_Stops Additional_Info  Price
# 10052    20:45        23:20       155           0         No info  31945

# %%
min(df[df['Total_Stops']==1]['Price'])
# Out:
# 3480

# %%
max(df[df['Total_Stops']==1]['Price'])
# Out:
# 79512

# %%
df[df['Price']==79512]
#Business class costs too much
# Out:
#       Unnamed: 0               Airline Date_of_Journey    Source Destination  \
# 2924        2924  Jet Airways Business      01/03/2019  Banglore   New Delhi
#
#                 Route Dep_Time Arrival_Time  Duration Total_Stops  \
# 2924  BLR → BOM → DEL    05:45        11:25       340           1
#
#      Additional_Info  Price
# 2924  Business class  79512

# %%
df[df['Total_Stops']==2].boxplot(column=['Price'])
# Out:
# <AxesSubplot:>

# %%
import pandas as pd

# %%
# df = pd.read_csv('flight_fare1.csv')

# %%
df
# Out:
#        Unnamed: 0      Airline Date_of_Journey    Source Destination  \
# 0               0       IndiGo      24/03/2019  Banglore   New Delhi
# 1               1    Air India       1/05/2019   Kolkata    Banglore
# 2               2  Jet Airways       9/06/2019     Delhi      Cochin
# 3               3       IndiGo      12/05/2019   Kolkata    Banglore
# 4               4       IndiGo      01/03/2019  Banglore   New Delhi
# ...           ...          ...             ...       ...         ...
# 10678       10678     Air Asia       9/04/2019   Kolkata    Banglore
# 10679       10679    Air India      27/04/2019   Kolkata    Banglore
# 10680       10680  Jet Airways      27/04/2019  Banglore       Delhi
# 10681       10681      Vistara      01/03/2019  Banglore   New Delhi
# 10682       10682    Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time  Arrival_Time  Duration Total_Stops  \
# ...

# %%
df['Additional_Info'].unique()
# Out:
# array(['No info', 'In-flight meal not included',
#        'No check-in baggage included', '1 Short layover', 'No Info',
#        '1 Long layover', 'Change airports', 'Business class',
#        'Red-eye flight', '2 Long layover'], dtype=object)

# %%
df[df['Additional_Info']=='Business class']
# Out:
#        Unnamed: 0               Airline Date_of_Journey    Source Destination  \
# 2924         2924  Jet Airways Business      01/03/2019  Banglore   New Delhi
# 3032         3032           Jet Airways      01/03/2019  Banglore   New Delhi
# 5372         5372  Jet Airways Business      01/03/2019  Banglore   New Delhi
# 10364       10364  Jet Airways Business      01/03/2019  Banglore   New Delhi
#
#                  Route Dep_Time Arrival_Time  Duration Total_Stops  \
# 2924   BLR → BOM → DEL    05:45        11:25       340           1
# 3032   BLR → BDQ → DEL    05:50        12:20       390           1
# 5372   BLR → BOM → DEL    05:45        12:25       400           1
# 10364  BLR → MAA → DEL    09:45        14:25       280           1
#
#       Additional_Info  Price
# 2924   Business class  79512
# 3032   Business class  28097
# 5372   Business class  62427
# 10364  Business class  57209

# %%
len(df['Arrival_Time'].unique())
# Out:
# 1343

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       10683 non-null  int64
#  1   Airline          10683 non-null  object
#  2   Date_of_Journey  10683 non-null  object
#  3   Source           10683 non-null  object
#  4   Destination      10683 non-null  object
#  5   Route            10683 non-null  object
#  6   Dep_Time         10683 non-null  object
#  7   Arrival_Time     10683 non-null  object
#  8   Duration         10683 non-null  int64
#  9   Total_Stops      10683 non-null  object
#  10  Additional_Info  10683 non-null  object
#  11  Price            10683 non-null  int64
# dtypes: int64(3), object(9)
# memory usage: 1001.7+ KB

# %%
df['Date_of_Journey'].unique()
# Out:
# array(['24/03/2019', '1/05/2019', '9/06/2019', '12/05/2019', '01/03/2019',
#        '24/06/2019', '12/03/2019', '27/05/2019', '1/06/2019',
#        '18/04/2019', '9/05/2019', '24/04/2019', '3/03/2019', '15/04/2019',
#        '12/06/2019', '6/03/2019', '21/03/2019', '3/04/2019', '6/05/2019',
#        '15/05/2019', '18/06/2019', '15/06/2019', '6/04/2019',
#        '18/05/2019', '27/06/2019', '21/05/2019', '06/03/2019',
#        '3/06/2019', '15/03/2019', '3/05/2019', '9/03/2019', '6/06/2019',
#        '24/05/2019', '09/03/2019', '1/04/2019', '21/04/2019',
#        '21/06/2019', '27/03/2019', '18/03/2019', '12/04/2019',
#        '9/04/2019', '1/03/2019', '03/03/2019', '27/04/2019'], dtype=object)

# %%
df
# Out:
#        Unnamed: 0      Airline Date_of_Journey    Source Destination  \
# 0               0       IndiGo      24/03/2019  Banglore   New Delhi
# 1               1    Air India       1/05/2019   Kolkata    Banglore
# 2               2  Jet Airways       9/06/2019     Delhi      Cochin
# 3               3       IndiGo      12/05/2019   Kolkata    Banglore
# 4               4       IndiGo      01/03/2019  Banglore   New Delhi
# ...           ...          ...             ...       ...         ...
# 10678       10678     Air Asia       9/04/2019   Kolkata    Banglore
# 10679       10679    Air India      27/04/2019   Kolkata    Banglore
# 10680       10680  Jet Airways      27/04/2019  Banglore       Delhi
# 10681       10681      Vistara      01/03/2019  Banglore   New Delhi
# 10682       10682    Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time  Arrival_Time  Duration Total_Stops  \
# ...

# %% [markdown]
# df.drop('Unnamed: 0',axis='columns',inplace=True)

# %% [markdown]
# df.drop('Arrival_Time_Hour',axis='columns',inplace=True)

# %% [markdown]
# temp_list = df.loc[3,'Arrival_Time'].split(':')
# print(int(temp_list[0]),
# int(temp_list[1].split()[0]))
# ####### df['Arr_Time_Hour']=0
# df['Arr_Time_Min'] = 0
# for i in range(len(df)):
#     temp_list = df.loc[i,'Arrival_Time'].split(':')
#     df.loc[i,'Arr_Time_Hour']=int(temp_list[0])
#     df.loc[i,'Arr_Time_Min'] = int(temp_list[1].split()[0])

# %%
df.drop('Arrival_Time',axis='columns',inplace=True)

# %%
df
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 0           IndiGo      24/03/2019  Banglore   New Delhi
# 1        Air India       1/05/2019   Kolkata    Banglore
# 2      Jet Airways       9/06/2019     Delhi      Cochin
# 3           IndiGo      12/05/2019   Kolkata    Banglore
# 4           IndiGo      01/03/2019  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10678     Air Asia       9/04/2019   Kolkata    Banglore
# 10679    Air India      27/04/2019   Kolkata    Banglore
# 10680  Jet Airways      27/04/2019  Banglore       Delhi
# 10681      Vistara      01/03/2019  Banglore   New Delhi
# 10682    Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time  Duration Total_Stops Additional_Info  \
# 0                  BLR → DEL    22:20       170           0         No info
# 1      CCU → IXR → BBI → BLR    05:50       445           2         No info
# ...

# %% [raw]
# # df['Dep_Time_Hour'] = 0
# # df['Dep_Time_Min'] = 0
# for i in range(len(df)):
#     df.loc[i,'Dep_Time_Hour']=int(df.loc[i,'Dep_Time'].split(':')[0])
#     df.loc[i,'Dep_Time_Min']=int(df.loc[i,'Dep_Time'].split(':')[1])

# %% [raw]
# df.drop('Dep_Time',axis='columns',inplace=True)

# %%
df.to_csv('flight_fare2.csv')

# %% [markdown]
# ### 18-01-2023

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('flight_fare2.csv')

# %%
df.head()
# Out:
#    Unnamed: 0      Airline Date_of_Journey    Source Destination  \
# 0           0       IndiGo      24/03/2019  Banglore   New Delhi
# 1           1    Air India       1/05/2019   Kolkata    Banglore
# 2           2  Jet Airways       9/06/2019     Delhi      Cochin
# 3           3       IndiGo      12/05/2019   Kolkata    Banglore
# 4           4       IndiGo      01/03/2019  Banglore   New Delhi
#
#                    Route  Duration  Total_Stops Additional_Info  Price  \
# 0              BLR → DEL       170            0         No info   3897
# 1  CCU → IXR → BBI → BLR       445            2         No info   7662
# 2  DEL → LKO → BOM → COK      1140            2         No info  13882
# 3        CCU → NAG → BLR       325            1         No info   6218
# 4        BLR → NAG → DEL       285            1         No info  13302
#
#    Arr_Time_Min  Arr_Time_Hour  Dep_Time_Hour  Dep_Time_Min
# 0            10            1.0             22            20
# ...

# %%
Arr_Time_Hour=df.groupby(['Arr_Time_Hour']).count()['Airline']

# %%
plt.rcParams["figure.figsize"] = (12,6)# it is in inches

# %%
plt.xticks([i for i in range(0,24)])
plt.plot(arrival_time,marker='o',ms=4,mfc='red')
for index,nbookings in enumerate(Arr_Time_Hour):
    plt.annotate(str(nbookings),xy=(index,nbookings+10))
font_title = {'family':'serif','color':'red','size':15}
font_label = {'family':'Georgia','color':'blue','size':15}
plt.xlabel("Arr_Time_Hour->",fontdict=font_label)
plt.ylabel("Number of arrived flight->",fontdict=font_label)
plt.title("Arrival of flight VS Time Analysis",fontdict = font_title)
plt.annotate("max_arrival",xy=(Arr_Time_Hour.idxmax(),max(Arr_Time_Hour))
             ,xytext = (Arr_Time_Hour.idxmax()+2,max(Arr_Time_Hour)),arrowprops=dict(facecolor='black',shrink=0.002,alpha=0.4))
plt.annotate("min_arrival",xy=(Arr_Time_Hour.idxmin(),min(Arr_Time_Hour))
             ,xytext = (Arr_Time_Hour.idxmin()+2,min(Arr_Time_Hour)-40),arrowprops=dict(facecolor='black',shrink=0.002,alpha=0.4))
plt.grid(alpha=0.5,ls='--')
plt.show()

# %% [markdown]
# ### Data says that maximum flights(1626) arrive around 7PM and minimun flights(47) arrive around 3AM

# %%
Dep_Time_Hour = df.groupby(['Dep_Time_Hour']).count()['Airline']

# %%
print(Dep_Time_Hour.idxmax())
# Out:
# 9

# %%
plt.xticks([i for i in range(0,24)])
plt.plot(Dep_Time_Hour,marker='o',ms=4,mfc='red')
for index,nbookings in enumerate(Dep_Time_Hour):
    plt.annotate(str(nbookings),xy=(index,nbookings+10))
font_title = {'family':'serif','color':'red','size':15}
font_label = {'family':'Georgia','color':'blue','size':15}
plt.xlabel("Dept_Time_Hour->",fontdict=font_label)
plt.ylabel("Number of flight departed->",fontdict=font_label)
plt.title("Departure of flight VS Time Analysis",fontdict = font_title)
plt.annotate("max_departures",xy=(Dep_Time_Hour.idxmax(),max(Dep_Time_Hour)),xytext = (Dep_Time_Hour.idxmax()+2,max(Dep_Time_Hour))
             ,arrowprops=dict(facecolor='black',shrink=0.002))
plt.annotate("min_departures",xy=(Dep_Time_Hour.idxmin(),min(Dep_Time_Hour)),xytext=(Dep_Time_Hour.idxmin()+2,min(Dep_Time_Hour))
             ,arrowprops=dict(facecolor='black',shrink=0.002))

plt.grid(alpha=0.5,ls='--')
plt.show()

# %% [markdown]
# ### Data implies that maximum flight departs around 9AM in the morning and minimum flight departs between 12PM to 2AM

# %%
df['Additional_Info'].unique()
# Out:
# array(['No info', 'In-flight meal not included',
#        'No check-in baggage included', '1 Short layover', 'No Info',
#        '1 Long layover', 'Change airports', 'Business class',
#        'Red-eye flight', '2 Long layover'], dtype=object)

# %%
additional_info = ['In-flight meal not included',
       'No check-in baggage included', '1 Short layover', 'No Info',
       '1 Long layover', 'Change airports', 'Business class',
       'Red-eye flight', '2 Long layover']

# %% [markdown]
# ### According to data, Jet Airways is the only Airline which does not provide In-Flight meal

# %%
df[(df['Additional_Info']==additional_info[0]) & (df['Airline']=='Jet Airways')]['Airline'].count()
# Out:
# 1886

# %%
min(df[(df['Additional_Info']==additional_info[0]) & (df['Airline']=='Jet Airways')]['Price'])
# Out:
# 1840

# %%
df.head()
# Out:
#    Unnamed: 0      Airline Date_of_Journey    Source Destination  \
# 0           0       IndiGo      24/03/2019  Banglore   New Delhi
# 1           1    Air India       1/05/2019   Kolkata    Banglore
# 2           2  Jet Airways       9/06/2019     Delhi      Cochin
# 3           3       IndiGo      12/05/2019   Kolkata    Banglore
# 4           4       IndiGo      01/03/2019  Banglore   New Delhi
#
#                    Route  Duration  Total_Stops Additional_Info  Price  \
# 0              BLR → DEL       170            0         No info   3897
# 1  CCU → IXR → BBI → BLR       445            2         No info   7662
# 2  DEL → LKO → BOM → COK      1140            2         No info  13882
# 3        CCU → NAG → BLR       325            1         No info   6218
# 4        BLR → NAG → DEL       285            1         No info  13302
#
#    Arr_Time_Min  Arr_Time_Hour  Dep_Time_Hour  Dep_Time_Min
# 0            10            1.0             22            20
# ...

# %%
df['Additional_Info'].unique()
# Out:
# array(['No info', 'In-flight meal not included',
#        'No check-in baggage included', '1 Short layover', 'No Info',
#        '1 Long layover', 'Change airports', 'Business class',
#        'Red-eye flight', '2 Long layover'], dtype=object)

# %%
for i in df['Additional_Info'].unique():
    print(i,max(df[(df['Additional_Info']==i)]['Price']),min(df[(df['Additional_Info']==i)]['Price']))
# Out:
# No info 54826 1759
# In-flight meal not included 19644 1840
# No check-in baggage included 6356 1965
# 1 Short layover 26743 26743
# No Info 8153 7917
# 1 Long layover 31825 7744
# Change airports 26092 13366
# Business class 79512 28097
# Red-eye flight 10873 10873
# 2 Long layover 26480 26480

# %%
df[(df['Additional_Info']=='No Info')]
# Out:
#       Unnamed: 0 Airline Date_of_Journey    Source Destination  \
# 795          795  IndiGo      01/03/2019  Banglore   New Delhi
# 2212        2212  IndiGo      01/03/2019  Banglore   New Delhi
# 9220        9220  IndiGo      01/03/2019  Banglore   New Delhi
#
#                 Route  Duration  Total_Stops Additional_Info  Price  \
# 795   BLR → HYD → DEL       295            1         No Info   8153
# 2212  BLR → HYD → DEL       260            1         No Info   7917
# 9220  BLR → HYD → DEL       285            1         No Info   8064
#
#       Arr_Time_Min  Arr_Time_Hour  Dep_Time_Hour  Dep_Time_Min
# 795             50           21.0             16            55
# 2212            35           20.0             16            15
# 9220             0           10.0              5            15

# %%
no_Info = df[(df['Additional_Info']=='No info')][['Price','Duration']].sort_values('Duration')

# %%
plt.plot(list(no_Info['Duration']),list(no_Info['Price']))

# %%
import pandas as pd
df = pd.read_csv('flight_fare2.csv')
df.head()
# Out:
#    Unnamed: 0      Airline Date_of_Journey    Source Destination  \
# 0           0       IndiGo      24/03/2019  Banglore   New Delhi
# 1           1    Air India       1/05/2019   Kolkata    Banglore
# 2           2  Jet Airways       9/06/2019     Delhi      Cochin
# 3           3       IndiGo      12/05/2019   Kolkata    Banglore
# 4           4       IndiGo      01/03/2019  Banglore   New Delhi
#
#                    Route  Duration  Total_Stops Additional_Info  Price  \
# 0              BLR → DEL       170            0         No info   3897
# 1  CCU → IXR → BBI → BLR       445            2         No info   7662
# 2  DEL → LKO → BOM → COK      1140            2         No info  13882
# 3        CCU → NAG → BLR       325            1         No info   6218
# 4        BLR → NAG → DEL       285            1         No info  13302
#
#    Arr_Time_Min  Arr_Time_Hour  Dep_Time_Hour  Dep_Time_Min
# 0            10            1.0             22            20
# ...

# %%
#splitting Date of journey into two columns that is Day of Journey

# %%
df['Day_of_Journey'] = pd.to_datetime(df['Date_of_Journey'],format='%d/%m/%Y').dt.day

# %%
df['Month_of_Journey'] = pd.to_datetime(df['Date_of_Journey'],format = '%d/%m/%Y').dt.month

# %%
df.head()
# Out:
#    Unnamed: 0      Airline Date_of_Journey    Source Destination  \
# 0           0       IndiGo      24/03/2019  Banglore   New Delhi
# 1           1    Air India       1/05/2019   Kolkata    Banglore
# 2           2  Jet Airways       9/06/2019     Delhi      Cochin
# 3           3       IndiGo      12/05/2019   Kolkata    Banglore
# 4           4       IndiGo      01/03/2019  Banglore   New Delhi
#
#                    Route  Duration  Total_Stops Additional_Info  Price  \
# 0              BLR → DEL       170            0         No info   3897
# 1  CCU → IXR → BBI → BLR       445            2         No info   7662
# 2  DEL → LKO → BOM → COK      1140            2         No info  13882
# 3        CCU → NAG → BLR       325            1         No info   6218
# 4        BLR → NAG → DEL       285            1         No info  13302
#
#    Arr_Time_Min  Arr_Time_Hour  Dep_Time_Hour  Dep_Time_Min  Day_of_Journey  \
# ...

# %%
##Droping Date_of_Journey,ROute,Unnamed columns since are of no use
df.drop('Date_of_Journey',axis=1,inplace=True)
df.drop('Route',axis=1,inplace=True)
df.drop('Unnamed: 0',axis=1,inplace=True)

# %%
df.to_csv("flight_fare3.csv",index=False)

# %%
pd.read_csv('flight_fare3.csv')
# Out:
#            Airline    Source Destination  Duration  Total_Stops  \
# 0           IndiGo  Banglore   New Delhi       170            0
# 1        Air India   Kolkata    Banglore       445            2
# 2      Jet Airways     Delhi      Cochin      1140            2
# 3           IndiGo   Kolkata    Banglore       325            1
# 4           IndiGo  Banglore   New Delhi       285            1
# ...            ...       ...         ...       ...          ...
# 10678     Air Asia   Kolkata    Banglore       150            0
# 10679    Air India   Kolkata    Banglore       155            0
# 10680  Jet Airways  Banglore       Delhi       180            0
# 10681      Vistara  Banglore   New Delhi       160            0
# 10682    Air India     Delhi      Cochin       500            2
#
#       Additional_Info  Price  Arr_Time_Min  Arr_Time_Hour  Dep_Time_Hour  \
# 0             No info   3897            10            1.0             22
# ...

# %%
df[df['Additional_Info']=='2 Long layover']
# Out:
#          Airline    Source Destination  Duration  Total_Stops Additional_Info  \
# 10511  Air India  Banglore   New Delhi      1600            2  2 Long layover
#
#        Price  Arr_Time_Min  Arr_Time_Hour  Dep_Time_Hour  Dep_Time_Min  \
# 10511  26480            25            9.0              6            45
#
#        Day_of_Journey  Month_of_Journey
# 10511               1                 3

# %%
df[df['Additional_Info']=='1 Long layover']
# Out:
#           Airline    Source Destination  Duration  Total_Stops  \
# 1043    Air India  Banglore   New Delhi       525            1
# 1044  Jet Airways     Delhi      Cochin      1090            2
# 1045    Air India   Kolkata    Banglore       895            2
# 1046  Jet Airways     Delhi      Cochin       450            1
# 2079    Air India  Banglore   New Delhi      1200            1
# ...           ...       ...         ...       ...          ...
# 9657    Air India  Banglore   New Delhi       950            1
# 9658  Jet Airways   Kolkata    Banglore       875            1
# 9659       IndiGo     Delhi      Cochin       810            1
# 9660  Jet Airways   Kolkata    Banglore       520            1
# 9661  Jet Airways   Kolkata    Banglore      1365            1
#
#      Additional_Info  Price  Arr_Time_Min  Arr_Time_Hour  Dep_Time_Hour  \
# 1043  1 Long layover  14594            50           19.0             11
# ...

# %%
df[df['Additional_Info']=='Business class']
# Out:
#                     Airline    Source Destination  Duration  Total_Stops  \
# 2924   Jet Airways Business  Banglore   New Delhi       340            1
# 3032            Jet Airways  Banglore   New Delhi       390            1
# 3033            Jet Airways  Banglore   New Delhi      1355            1
# 5372   Jet Airways Business  Banglore   New Delhi       400            1
# 5373              Air India  Banglore   New Delhi       655            2
# 10364  Jet Airways Business  Banglore   New Delhi       280            1
# 10365               Vistara  Banglore       Delhi       170            0
# 10366     Multiple carriers     Delhi      Cochin       870            1
# 10367           Jet Airways    Mumbai   Hyderabad        90            0
#
#       Additional_Info  Price  Arr_Time_Min  Arr_Time_Hour  Dep_Time_Hour  \
# 2924   Business class  79512            25           11.0              5
# 3032   Business class  28097            20           12.0              5
# ...

# %%
df['Additional_Info']=df['Additional_Info'].replace('No info','No Info')

# %%
df.to_csv('flight_fare4.csv',index=False)

# %%
import pandas as pd
df = pd.read_csv('flight_fare4.csv')

# %%
df.head()
# Out:
#        Airline    Source Destination  Duration  Total_Stops Additional_Info  \
# 0       IndiGo  Banglore   New Delhi       170            0         No Info
# 1    Air India   Kolkata    Banglore       445            2         No Info
# 2  Jet Airways     Delhi      Cochin      1140            2         No Info
# 3       IndiGo   Kolkata    Banglore       325            1         No Info
# 4       IndiGo  Banglore   New Delhi       285            1         No Info
#
#    Price  Arr_Time_Min  Arr_Time_Hour  Dep_Time_Hour  Dep_Time_Min  \
# 0   3897            10            1.0             22            20
# 1   7662            15           13.0              5            50
# 2  13882            25            4.0              9            25
# 3   6218            30           23.0             18             5
# 4  13302            35           21.0             16            50
#
#    Day_of_Journey  Month_of_Journey
# 0              24                 3
# ...

# %%
df[df['Airline']=='Trujet']
# Out:
#      Airline  Source Destination  Duration  Total_Stops  \
# 2878  Trujet  Mumbai   Hyderabad       195            1
#
#                   Additional_Info  Price  Arr_Time_Min  Arr_Time_Hour  \
# 2878  In-flight meal not included   4140            20           16.0
#
#       Dep_Time_Hour  Dep_Time_Min  Day_of_Journey  Month_of_Journey
# 2878             13             5               6                 3

# %%
index = df[df['Airline']=='Trujet'].index
print(index)
df.drop(index,inplace=True)
# Out:
# Int64Index([2878], dtype='int64')

# %%
df[df['Airline']=='Trujet']
# Out:
# Empty DataFrame
# Columns: [Airline, Source, Destination, Duration, Total_Stops, Additional_Info, Price, Arr_Time_Min, Arr_Time_Hour, Dep_Time_Hour, Dep_Time_Min, Day_of_Journey, Month_of_Journey]
# Index: []

# %%
from sklearn.model_selection import train_test_split

# %%
# split the data into train and test set
train_data, test_data = train_test_split(df, test_size=0.2, shuffle=True)

# %%
train_data[train_data['Airline']=='Multiple carriers Premium economy']
# Out:
#                                 Airline Source Destination  Duration  \
# 4627  Multiple carriers Premium economy  Delhi      Cochin       620
# 5836  Multiple carriers Premium economy  Delhi      Cochin       680
# 5673  Multiple carriers Premium economy  Delhi      Cochin       770
# 5090  Multiple carriers Premium economy  Delhi      Cochin       440
# 6591  Multiple carriers Premium economy  Delhi      Cochin       395
# 9249  Multiple carriers Premium economy  Delhi      Cochin       395
# 1799  Multiple carriers Premium economy  Delhi      Cochin       810
#
#       Total_Stops               Additional_Info  Price  Arr_Time_Min  \
# 4627            1   In-flight meal not included  10161            15
# 5836            1  No check-in baggage included  14629            50
# 5673            1   In-flight meal not included  14629            50
# 5090            1  No check-in baggage included  11269            20
# ...

# %%
test_data[test_data['Airline']=='Multiple carriers Premium economy']
# Out:
#                                 Airline Source Destination  Duration  \
# 6601  Multiple carriers Premium economy  Delhi      Cochin       395
# 6470  Multiple carriers Premium economy  Delhi      Cochin       725
# 4718  Multiple carriers Premium economy  Delhi      Cochin       900
# 717   Multiple carriers Premium economy  Delhi      Cochin       705
# 5489  Multiple carriers Premium economy  Delhi      Cochin       570
# 9253  Multiple carriers Premium economy  Delhi      Cochin       480
#
#       Total_Stops              Additional_Info  Price  Arr_Time_Min  \
# 6601            1  In-flight meal not included  13369            35
# 6470            1  In-flight meal not included   9845             0
# 4718            1  In-flight meal not included   9845             0
# 717             1  In-flight meal not included  10161            15
# 5489            1  In-flight meal not included  11269            30
# 9253            1  In-flight meal not included  11269            30
#
# ...

# %%
#saving train data and test data separately
train_data.to_csv('train_data.csv',index=False)
test_data.to_csv('test_data.csv',index=False)

# %%
train_data.head()
# Out:
#                 Airline    Source Destination  Duration  Total_Stops  \
# 2254        Jet Airways   Kolkata    Banglore      1335            1
# 9689        Jet Airways  Banglore   New Delhi       365            1
# 881           Air India   Kolkata    Banglore      1700            2
# 9846  Multiple carriers     Delhi      Cochin       495            2
# 7309        Jet Airways   Kolkata    Banglore       395            1
#
#                    Additional_Info  Price  Arr_Time_Min  Arr_Time_Hour  \
# 2254   In-flight meal not included  10844            15           18.0
# 9689   In-flight meal not included  22270            45            0.0
# 881   No check-in baggage included  15532            45           13.0
# 9846   In-flight meal not included  11966            20           21.0
# 7309   In-flight meal not included  12384            35           23.0
#
#       Dep_Time_Hour  Dep_Time_Min  Day_of_Journey  Month_of_Journey
# ...

# %%
test_data.head()
# Out:
#                 Airline    Source Destination  Duration  Total_Stops  \
# 7887        Jet Airways  Banglore   New Delhi       405            1
# 144   Multiple carriers     Delhi      Cochin       710            1
# 9187          Air India   Kolkata    Banglore       610            2
# 9539          Air India     Delhi      Cochin      1600            2
# 9583        Jet Airways   Kolkata    Banglore       450            1
#
#                   Additional_Info  Price  Arr_Time_Min  Arr_Time_Hour  \
# 7887  In-flight meal not included   9134            25           18.0
# 144   In-flight meal not included   9486            55            0.0
# 9187              Change airports  10697            30           18.0
# 9539  In-flight meal not included  11806            40            7.0
# 9583  In-flight meal not included   7594            40            4.0
#
#       Dep_Time_Hour  Dep_Time_Min  Day_of_Journey  Month_of_Journey
# ...

# %%
df.groupby('Airline').count()
# Out:
#                                    Source  Destination  Duration  Total_Stops  \
# Airline
# Air Asia                              319          319       319          319
# Air India                            1752         1752      1752         1752
# GoAir                                 194          194       194          194
# IndiGo                               2053         2053      2053         2053
# Jet Airways                          3849         3849      3849         3849
# Jet Airways Business                    6            6         6            6
# Multiple carriers                    1196         1196      1196         1196
# Multiple carriers Premium economy      13           13        13           13
# SpiceJet                              818          818       818          818
# Trujet                                  1            1         1            1
# Vistara                               479          479       479          479
# ...

# %%
df.groupby('Source').count()
# Out:
#           Airline  Destination  Duration  Total_Stops  Additional_Info  Price  \
# Source
# Banglore     2197         2197      2197         2197             2197   2197
# Chennai       381          381       381          381              381    381
# Delhi        4537         4537      4537         4537             4537   4537
# Kolkata      2871         2871      2871         2871             2871   2871
# Mumbai        697          697       697          697              697    697
#
#           Arr_Time_Min  Arr_Time_Hour  Dep_Time_Hour  Dep_Time_Min  \
# Source
# Banglore          2197           2197           2197          2197
# Chennai            381            381            381           381
# Delhi             4537           4537           4537          4537
# Kolkata           2871           2871           2871          2871
# Mumbai             697            697            697           697
#
#           Day_of_Journey  Month_of_Journey
# Source
# ...

# %%
df.groupby('Destination').count()
# Out:
#              Airline  Source  Duration  Total_Stops  Additional_Info  Price  \
# Destination
# Banglore        2871    2871      2871         2871             2871   2871
# Cochin          4537    4537      4537         4537             4537   4537
# Delhi           1265    1265      1265         1265             1265   1265
# Hyderabad        697     697       697          697              697    697
# Kolkata          381     381       381          381              381    381
# New Delhi        932     932       932          932              932    932
#
#              Arr_Time_Min  Arr_Time_Hour  Dep_Time_Hour  Dep_Time_Min  \
# Destination
# Banglore             2871           2871           2871          2871
# Cochin               4537           4537           4537          4537
# Delhi                1265           1265           1265          1265
# Hyderabad             697            697            697           697
# ...

# %%
df['Destination'].unique()
# Out:
# array(['New Delhi', 'Banglore', 'Cochin', 'Kolkata', 'Delhi', 'Hyderabad'],
#       dtype=object)

# %%
df = pd.read_csv('flight_fare2.csv')

# %%
df.groupby('Route').count().sort_values(by='Airline',ascending=False)
# Out:
#                        Unnamed: 0  Airline  Date_of_Journey  Source  \
# Route
# DEL → BOM → COK              2376     2376             2376    2376
# BLR → DEL                    1552     1552             1552    1552
# CCU → BOM → BLR               979      979              979     979
# CCU → BLR                     724      724              724     724
# BOM → HYD                     621      621              621     621
# ...                           ...      ...              ...     ...
# CCU → IXZ → MAA → BLR           1        1                1       1
# BOM → JAI → DEL → HYD           1        1                1       1
# BOM → BBI → HYD                 1        1                1       1
# CCU → RPR → HYD → BLR           1        1                1       1
# BLR → BOM → IXC → DEL           1        1                1       1
#
#                        Destination  Duration  Total_Stops  Additional_Info  \
# Route
# ...
